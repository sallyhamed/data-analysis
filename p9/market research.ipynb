# %% [markdown]
# # Marketeers Test

# %% [markdown]
# ### Q1: Import Libraries needed

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Q2: Read the 3 excel files(Market_A,Market_B,Market_C) from the data folder in df_A,df_B,df_C respectively.
# ### And show the first 10 rows in df_B

# %%
df_A= pd.read_csv('Market_A.csv')
df_B= pd.read_csv('Market_B.csv')
df_C= pd.read_csv('Market_C.csv')

# %%
df_B.head(10)
# Out:
#    Unnamed: 0 Branch      City Customer type  Gender            Product line  \
# 0           9      B  Mandalay        Member  Female      Food and beverages
# 1          10      B  Mandalay        Member  Female     Fashion accessories
# 2          11      B  Mandalay        Member    Male  Electronic accessories
# 3          15      B  Mandalay        Member  Female       Sports and travel
# 4          19      B  Mandalay        Normal  Female      Home and lifestyle
# 5          21      B  Mandalay        Normal    Male       Health and beauty
# 6          22      B  Mandalay        Normal    Male      Home and lifestyle
# 7          26      B  Mandalay        Normal    Male     Fashion accessories
# 8          28      B  Mandalay        Normal  Female      Food and beverages
# 9          30      B  Mandalay        Normal    Male     Fashion accessories
#
#    Unit price  Quantity   Tax 5%     Total      Payment    cogs  \
# ...

# %% [markdown]
# ### Q3: For each dataframe  drop the column "Unnamed: 0" and save it to the dataframe and print the first 10 rows from df_C

# %%
df_A.drop("Unnamed: 0", axis=1,inplace=True)
df_B.drop("Unnamed: 0", axis=1,inplace=True)
df_C.drop("Unnamed: 0", axis=1,inplace=True)

# %%
df_C.head(10)
# Out:
#   Branch       City Customer type  Gender            Product line  Unit price  \
# 0      C  Naypyitaw        Normal  Female  Electronic accessories       15.28
# 1      C  Naypyitaw        Normal    Male  Electronic accessories       85.39
# 2      C  Naypyitaw        Normal  Female      Home and lifestyle       73.56
# 3      C  Naypyitaw        Member    Male  Electronic accessories       86.04
# 4      C  Naypyitaw        Member  Female      Food and beverages       99.42
# 5      C  Naypyitaw        Member  Female       Sports and travel       68.12
# 6      C  Naypyitaw        Normal  Female       Health and beauty       54.92
# 7      C  Naypyitaw        Member    Male      Home and lifestyle       56.11
# 8      C  Naypyitaw        Member  Female      Food and beverages       98.70
# 9      C  Naypyitaw        Member    Male       Health and beauty       15.37
#
#    Quantity   Tax 5%     Total  Payment    cogs  gross margin percentage  \
# ...

# %% [markdown]
# ### Q4: Join the 3 dataframes into one dataframe named "total_df":

# %%
total_df = pd.concat([df_A, df_B,df_C], sort=False)

# %%
total_df
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        A     Yangon        Normal    Male      Home and lifestyle
# 2        A     Yangon        Member    Male       Health and beauty
# 3        A     Yangon        Normal    Male       Sports and travel
# 4        A     Yangon        Member  Female  Electronic accessories
# ..     ...        ...           ...     ...                     ...
# 323      C  Naypyitaw        Normal    Male       Health and beauty
# 324      C  Naypyitaw        Normal    Male  Electronic accessories
# 325      C  Naypyitaw        Member    Male  Electronic accessories
# 326      C  Naypyitaw        Member  Female  Electronic accessories
# 327      C  Naypyitaw        Normal    Male       Health and beauty
#
#      Unit price  Quantity   Tax 5%     Total      Payment    cogs  \
# 0         74.69         7  26.1415  548.9715      Ewallet  522.83
# ...

# %% [markdown]
# ### Q5: Show info for total_df

# %%
total_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 327
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   branch                   1000 non-null   object
#  1   city                     1000 non-null   object
#  2   customer_type            1000 non-null   object
#  3   gender                   1000 non-null   object
#  4   product_line             1000 non-null   object
#  5   unit_price               1000 non-null   float64
#  6   quantity                 1000 non-null   int64
#  7   tax_5%                   1000 non-null   float64
#  8   total                    1000 non-null   float64
#  9   payment                  1000 non-null   object
#  10  cogs                     1000 non-null   float64
#  11  gross_margin_percentage  1000 non-null   float64
#  12  gross_income             1000 non-null   float64
#  13  rating                   1000 non-null   float64
# ...

# %%
total_df.rename(columns=lambda x: x.strip().lower().replace(" ", "_"), inplace=True)

# %% [markdown]
# ### Q6:For each categorical column in total_df print how many unique values are there in the column and print them in this format :
#
# ##### "The number of unique values in {column_name} is :{number of unique values} and they are:{list of unique values}"

# %%
total_df.columns
# Out:
# Index(['branch', 'city', 'customer_type', 'gender', 'product_line',
#        'unit_price', 'quantity', 'tax_5%', 'total', 'payment', 'cogs',
#        'gross_margin_percentage', 'gross_income', 'rating'],
#       dtype='object')

# %%
#total_df[['branch', 'city', 'customer_type', 'gender', 'product_line', 'payment']].agg(['nunique','count','unique'])
total_df[['branch', 'city', 'customer_type', 'gender', 'product_line', 'payment']].agg(['nunique','unique'])
# Out:
#             branch                           city     customer_type  \
# nunique          3                              3                 2
# unique   [A, B, C]  [Yangon, Mandalay, Naypyitaw]  [Member, Normal]
#
#                  gender                                       product_line  \
# nunique               2                                                  6
# unique   [Female, Male]  [Health and beauty, Home and lifestyle, Sports...
#
#                               payment
# nunique                             3
# unique   [Ewallet, Credit card, Cash]

# %%
total_df.nunique()
# Out:
# branch                       3
# city                         3
# customer_type                2
# gender                       2
# product_line                 6
# unit_price                 943
# quantity                    10
# tax_5%                     990
# total                      990
# payment                      3
# cogs                       990
# gross_margin_percentage      1
# gross_income               990
# rating                      61
# dtype: int64

# %%
total_df.city.value_counts()
# Out:
# Yangon       340
# Mandalay     332
# Naypyitaw    328
# Name: city, dtype: int64

# %%
total_df.branch.value_counts()
# Out:
# A    340
# B    332
# C    328
# Name: branch, dtype: int64

# %%
total_df.customer_type .value_counts()
# Out:
# Member    501
# Normal    499
# Name: customer_type, dtype: int64

# %%
total_df.gender.value_counts()
# Out:
# Female    501
# Male      499
# Name: gender, dtype: int64

# %%
total_df.product_line.value_counts()
# Out:
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: product_line, dtype: int64

# %%
total_df.payment.value_counts()
# Out:
# Ewallet        345
# Cash           344
# Credit card    311
# Name: payment, dtype: int64

# %% [markdown]
# ### Q7:For each numerical column print the mean,median rounded to 2 decimals and print them in this format :
# ##### "For {column name},the mean is:{mean},the median is {median},the mode is {mode}"

# %%
total_df.agg(['mean','median']).round(decimals=2)
# Out:
#         unit_price  quantity  tax_5%   total    cogs  gross_margin_percentage  \
# mean         55.67      5.51   15.38  322.97  307.59                     4.76
# median       55.23      5.00   12.09  253.85  241.76                     4.76
#
#         gross_income  rating
# mean           15.38    6.97
# median         12.09    7.00

# %%
total_df.mode(numeric_only=True).round(decimals = 2)
# Out:
#    unit_price  quantity  tax_5%   total    cogs  gross_margin_percentage  \
# 0       83.77      10.0     3.7   87.23   83.08                     4.76
# 1         NaN       NaN     NaN   93.74   89.28                      NaN
# 2         NaN       NaN     NaN  175.92  167.54                      NaN
# 3         NaN       NaN     NaN  189.09  180.09                      NaN
# 4         NaN       NaN     NaN  216.85  206.52                      NaN
# 5         NaN       NaN     NaN  217.63  207.27                      NaN
# 6         NaN       NaN     NaN  263.97  251.40                      NaN
# 7         NaN       NaN     NaN  276.95  263.76                      NaN
# 8         NaN       NaN     NaN  470.99  448.56                      NaN
# 9         NaN       NaN     NaN  829.08  789.60                      NaN
#
#    gross_income  rating
# 0           3.7     6.0
# 1           NaN     NaN
# 2           NaN     NaN
# 3           NaN     NaN
# 4           NaN     NaN
# ...

# %%
#np.round(total_df.mean(),decimals = 2)
total_df.mean().round(decimals = 2)
# Out:
# unit_price                  55.67
# quantity                     5.51
# tax_5%                      15.38
# total                      322.97
# cogs                       307.59
# gross_margin_percentage      4.76
# gross_income                15.38
# rating                       6.97
# dtype: float64

# %%
total_df.median().round(decimals = 2)
# Out:
# unit_price                  55.23
# quantity                     5.00
# tax_5%                      12.09
# total                      253.85
# cogs                       241.76
# gross_margin_percentage      4.76
# gross_income                12.09
# rating                       7.00
# dtype: float64

# %% [markdown]
# ### Q8: print description of total_df

# %%
total_df.describe()
# Out:
#         unit_price     quantity       tax_5%        total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross_margin_percentage  gross_income      rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %% [markdown]
# ### Q9:Filter total_df with filters ("Branch"='A',"Customer type"='Normal')

# %%
#total_df=total_df.query('branch =="A"'&'customer_type =="Normal"')
df = total_df[(total_df.branch =="A") & (total_df.customer_type =="Normal")]
df
# Out:
#     branch    city customer_type  gender            product_line  unit_price  \
# 1        A  Yangon        Normal    Male      Home and lifestyle       46.33
# 3        A  Yangon        Normal    Male       Sports and travel       86.31
# 6        A  Yangon        Normal  Female  Electronic accessories       46.95
# 7        A  Yangon        Normal    Male      Food and beverages       43.19
# 8        A  Yangon        Normal  Female       Health and beauty       71.38
# ..     ...     ...           ...     ...                     ...         ...
# 332      A  Yangon        Normal  Female      Food and beverages       74.66
# 333      A  Yangon        Normal    Male       Health and beauty       58.15
# 335      A  Yangon        Normal  Female      Food and beverages       56.56
# 336      A  Yangon        Normal    Male  Electronic accessories       58.03
# 338      A  Yangon        Normal    Male      Home and lifestyle       65.82
#
# ...

# %% [markdown]
# ### Q10:For any column of type float apply round function to round the values in each row to 2 decimal places only And show the first few rows to show first few rows

# %%
total_df = total_df.round(decimals = 2)

total_df.head()
# Out:
#   branch    city customer_type  gender            product_line  unit_price  \
# 0      A  Yangon        Member  Female       Health and beauty       74.69
# 1      A  Yangon        Normal    Male      Home and lifestyle       46.33
# 2      A  Yangon        Member    Male       Health and beauty       58.22
# 3      A  Yangon        Normal    Male       Sports and travel       86.31
# 4      A  Yangon        Member  Female  Electronic accessories       68.84
#
#    quantity  tax_5%   total      payment    cogs  gross_margin_percentage  \
# 0         7   26.14  548.97      Ewallet  522.83                     4.76
# 1         7   16.22  340.53  Credit card  324.31                     4.76
# 2         8   23.29  489.05      Ewallet  465.76                     4.76
# 3         7   30.21  634.38      Ewallet  604.17                     4.76
# 4         6   20.65  433.69      Ewallet  413.04                     4.76
#
#    gross_income  rating
# 0         26.14     9.1
# ...

# %% [markdown]
# ### Q11:For each unique value in Branch column compute the sum of the total_column and save it as a datframe with the name "total_per_branch"

# %%
total_df.branch.value_counts()
# Out:
# A    340
# B    332
# C    328
# Name: branch, dtype: int64

# %%
total_per_branch=pd.DataFrame({'A':[340] ,'B':[332],'C':[328] })
total_per_branch
# Out:
#      A    B    C
# 0  340  332  328

# %% [markdown]
# ### Q12:Check if males and females are equally presented in total_df and then compute the total sum for each gender and save it in a dataframe "total_per_gender"

# %%
#total_df[total_df.gender=='Male'].count()==total_df[total_df.gender=='Female'].count()
total_df.gender.value_counts().Male==total_df.gender.value_counts().Female
# Out:
# False

# %%
total_df.gender.value_counts()
#not equal
# Out:
# Female    501
# Male      499
# Name: gender, dtype: int64

# %%
total_per_gender=pd.DataFrame({'Female':[501] ,'Male':[499] })
total_per_gender
# Out:
#    Female  Male
# 0     501   499

# %% [markdown]
# ### Q13:Which of the payment methods is the most common?

# %%
total_df.payment.max()
# Out:
# 'Ewallet'

# %%
total_df.payment.value_counts()
# Ewallet
# Out:
# Ewallet        345
# Cash           344
# Credit card    311
# Name: payment, dtype: int64

# %% [markdown]
# ### Q14:Group By "Product line" and "Gender" and compute the mean of each "gender" in each " Product line"

# %%
total_df.groupby(['product_line','gender']).mean()
# Out:
#                                unit_price  quantity     tax_5%       total  \
# product_line           gender
# Electronic accessories Female   52.051548  5.809524  15.363958  322.643125
#                        Male     55.016744  5.616279  15.080570  316.691965
# Fashion accessories    Female   55.526979  5.520833  15.097917  317.056250
#                        Male     59.058049  4.536585  13.860915  291.079207
# Food and beverages     Female   60.090333  5.711111  17.550750  368.565750
#                        Male     51.635833  5.214286  13.023768  273.499125
# Health and beauty      Female   51.089219  5.359375  13.810258  290.015414
#                        Male     57.592841  5.806818  16.576165  348.099460
# Home and lifestyle     Female   57.242532  6.303797  18.105411  380.213639
#                        Male     53.438889  5.098765  14.006488  294.136241
# Sports and travel      Female   54.367273  5.636364  15.462511  324.712739
# ...

# %% [markdown]
# ### Q15:What is the Product line/s that has the highest unit price?

# %%
total_df.groupby(['product_line'])['unit_price'].max()
#Sports and travel
# Out:
# product_line
# Electronic accessories    99.73
# Fashion accessories       99.89
# Food and beverages        99.79
# Health and beauty         99.96
# Home and lifestyle        99.92
# Sports and travel         99.96
# Name: unit_price, dtype: float64

# %% [markdown]
# ### Q16:In the same folder ,create a new folder called "output".Output total_df into a new file called "total.csv" in the output folder

# %%
total_df.to_csv('total.csv',index=False)
